# %%
import pandas as pd

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum"]

pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3           Rum
# dtype: object

# %%
lottery = [4,3,5,8,555,48,52,587]

# %%
pd.Series(lottery)
# Out:
# 0      4
# 1      3
# 2      5
# 3      8
# 4    555
# 5     48
# 6     52
# 7    587
# dtype: int64

# %%
recipe = {
  "Flour": True,
  "Sugar": True,
  "Salt": False
}
pd.Series(recipe)
# Out:
# Flour     True
# Sugar     True
# Salt     False
# dtype: bool

# %%
about_me = ["Beautiful", "Smart", "Kind", "Sweet"]

# %%
a = pd.Series(about_me)

# %%
a.values
# Out:
# array(['Beautiful', 'Smart', 'Kind', 'Sweet'], dtype=object)

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
a.dtype
# Out:
# dtype('O')

# %%
prices = [2.55, 4222,0.8]

# %%
pd.Series(prices)
s = pd.Series(prices)

# %%
s.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       2.55
# 1    4222.00
# 2       0.80
# dtype: float64>

# %%
s.sum()
# Out:
# 4225.35

# %%
s.mean()
# Out:
# 1408.45

# %%
s.corr
# Out:
# <bound method Series.corr of 0       2.55
# 1    4222.00
# 2       0.80
# dtype: float64>

# %%
s.product()
# Out:
# 8612.88

# %%
fruit = ["Apple", "Banana", "Blueburry", "Orange"]
weekdays = ["Monday", "Tuesday","Wednesday","Thuesday"]

s = pd.Series(data = fruit,index = weekdays)

# %%
s
# Out:
# Monday           Apple
# Tuesday         Banana
# Wednesday    Blueburry
# Thuesday        Orange
# dtype: object

# %% [markdown]
# # READ CSV AND INTROD

# %%
import pandas as pd

# %%
Quba = pd.read_csv("Quba.csv")

# %%
Quba.tail(10)
max(Quba)
# Out:
# 'Что, по Вашему мнению, обязательно должны сделать власти для скорейшего и прочного закрепления Азербайджана в Карабахе после разминирования и создания базисной инфраструктуры (дороги, электрификация, водоснабжение)?'

# %%
Quba.dtypes
Quba.values
# Out:
# array([[nan, nan, nan, ..., 'Response', 'Response', 'Response'],
#        [12360138360.0, 398841011.0, '01/27/2021 11:07:44 PM', ...,
#         '1.\tПоложительно', '2.\tОтрицательно', '2.\tОтрицательно'],
#        [12360115115.0, 398841011.0, '01/27/2021 11:01:04 PM', ...,
#         '1.\tПоложительно', '3.\tНейтрально/Безразлично',
#         '3.\tНейтрально/Безразлично'],
#        ...,
#        [12313398212.0, 398841011.0, '01/11/2021 02:04:58 PM', ...,
#         '1.\tПоложительно', '3.\tНейтрально/Безразлично',
#         '3.\tНейтрально/Безразлично'],
#        [12313316491.0, 398841011.0, '01/11/2021 01:21:18 PM', ...,
#         '1.\tПоложительно', '3.\tНейтрально/Безразлично',
#         '3.\tНейтрально/Безразлично'],
#        [12313298257.0, 398841011.0, '01/11/2021 01:11:20 PM', ...,
#         '1.\tПоложительно', '2.\tОтрицательно', '2.\tОтрицательно']],
#       dtype=object)

# %%
import pandas as pd
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True )

# %%
pokemon.head(11)
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# 5      Charizard
# 6       Squirtle
# 7      Wartortle
# 8      Blastoise
# 9       Caterpie
# 10       Metapod
# Name: Pokemon, dtype: object

# %%
pokemon.tail()
# Out:
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
len(pokemon)
# Out:
# 721

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
list(pokemon)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
import pandas as pd
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True )

# %%
pokemon.is_unique
# Out:
# True

# %%
Quba.is_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-28fca00344c1> in <module>
# ----> 1 Quba.is_unique
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'is_unique'

# %%
Quba.size
# Out:
# 128688

# %%
pokemon.size
# Out:
# 721

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
import pandas as pd
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True )

# %%
pokemon.sort_values().head(6)
# Out:
# 459     Abomasnow
# 62           Abra
# 358         Absol
# 616      Accelgor
# 680     Aegislash
# 141    Aerodactyl
# Name: Pokemon, dtype: object

# %%
pokemon.sort_values(ascending = False)
# Out:
# 717      Zygarde
# 633     Zweilous
# 40         Zubat
# 569        Zorua
# 570      Zoroark
#          ...
# 680    Aegislash
# 616     Accelgor
# 358        Absol
# 62          Abra
# 459    Abomasnow
# Name: Pokemon, Length: 721, dtype: object

# %%
pokemon.sort_values(ascending= False).head(99)
# Out:
# 717      Zygarde
# 633     Zweilous
# 40         Zubat
# 569        Zorua
# 570      Zoroark
#          ...
# 71     Tentacool
# 215    Teddiursa
# 127       Tauros
# 464    Tangrowth
# 113      Tangela
# Name: Pokemon, Length: 99, dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv")
google = pd.read_csv("google_stock_price.csv")

# %%
google.astype
# Out:
# <bound method NDFrame.astype of       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# ...           ...
# 3007       772.88
# 3008       771.07
# 3009       773.18
# 3010       771.61
# 3011       782.22
#
# [3012 rows x 1 columns]>

# %%
google.sort_values
# Out:
# <bound method DataFrame.sort_values of       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# ...           ...
# 3007       772.88
# 3008       771.07
# 3009       773.18
# 3010       771.61
# 3011       782.22
#
# [3012 rows x 1 columns]>

# %%
google
# Out:
#       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# ...           ...
# 3007       772.88
# 3008       771.07
# 3009       773.18
# 3010       771.61
# 3011       782.22
#
# [3012 rows x 1 columns]

# %%
max(google)
# Out:
# 'Stock Price'

# %%
min(google)
# Out:
# 'Stock Price'

# %%
google.sort_values
# Out:
# <bound method DataFrame.sort_values of       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# ...           ...
# 3007       772.88
# 3008       771.07
# 3009       773.18
# 3010       771.61
# 3011       782.22
#
# [3012 rows x 1 columns]>

# %% [markdown]
# # Sort Values and Index

# %%
pokemon = pd.read_csv("pokemon.csv")
google = pd.read_csv("google_stock_price.csv")

# %%
pokemon.sort_index(ascending=False)
# Out:
#         Pokemon     Type
# 720   Volcanion     Fire
# 719       Hoopa  Psychic
# 718     Diancie     Rock
# 717     Zygarde   Dragon
# 716     Yveltal     Dark
# ..          ...      ...
# 4    Charmeleon     Fire
# 3    Charmander     Fire
# 2      Venusaur    Grass
# 1       Ivysaur    Grass
# 0     Bulbasaur    Grass
#
# [721 rows x 2 columns]

# %%
import pandas as pd
# Assume pandas has already been imported and assigned to the alias "pd".

flavors = ["Spicy Sweet Chili", "Cool Ranch", "Nacho Cheese", "Salsa Verde"]

# %%
flavors.sort()
