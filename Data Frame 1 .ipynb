# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.head(12)
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
#
# ...

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
rev = pd.read_csv("revenue.csv", index_col= "Date")

# %%
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.Name

output = None

# %%
nba["Salary"]
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
## TWO COLUMNS IN FRAME

# %%
nba[["Salary" , "Name"]]
# Out:
#         Salary           Name
# 0    7730337.0  Avery Bradley
# 1    6796117.0    Jae Crowder
# 2          NaN   John Holland
# 3    1148640.0    R.J. Hunter
# 4    5000000.0  Jonas Jerebko
# ..         ...            ...
# 453  2433333.0   Shelvin Mack
# 454   900000.0      Raul Neto
# 455  2900000.0   Tibor Pleiss
# 456   947276.0    Jeff Withey
# 457        NaN            NaN
#
# [458 rows x 2 columns]

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba["Sport"] = "Footbal"

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary    Sport
# 0                Texas  7730337.0  Footbal
# ...

# %%
nba.insert(3, column="Side" , value= "Right")

# %%
nba
# Out:
#               Name            Team  Number   Side Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Right       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Right       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Right       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Right       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Right       PF  29.0   6-10
# ..             ...             ...     ...    ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Right       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Right       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Right        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Right        C  26.0    7-0
# 457            NaN             NaN     NaN  Right      NaN   NaN    NaN
#
#      Weight            College     Salary    Sport
# 0     180.0              Texas  7730337.0  Footbal
# ...

# %%
#REVIEW SERIES DELEELELELEETTE

# %%
nba.head(3)
# Out:
#             Name            Team  Number   Side Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0  Right       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0  Right       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0  Right       SG  27.0    6-5   205.0
#
#              College     Salary    Sport
# 0              Texas  7730337.0  Footbal
# 1          Marquette  6796117.0  Footbal
# 2  Boston University        NaN  Footbal

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Brooklyn Nets             15
# San Antonio Spurs         15
# Indiana Pacers            15
# Denver Nuggets            15
# Detroit Pistons           15
# Atlanta Hawks             15
# Toronto Raptors           15
# Dallas Mavericks          15
# Golden State Warriors     15
# Los Angeles Clippers      15
# Oklahoma City Thunder     15
# Miami Heat                15
# Sacramento Kings          15
# Philadelphia 76ers        15
# Cleveland Cavaliers       15
# Phoenix Suns              15
# Utah Jazz                 15
# Charlotte Hornets         15
# Boston Celtics            15
# Washington Wizards        15
# Los Angeles Lakers        15
# Chicago Bulls             15
# Portland Trail Blazers    15
# Houston Rockets           15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.tail(3)
# Out:
#              Name       Team  Number   Side Position   Age Height  Weight  \
# 455  Tibor Pleiss  Utah Jazz    21.0  Right        C  26.0    7-3   256.0
# 456   Jeff Withey  Utah Jazz    24.0  Right        C  26.0    7-0   231.0
# 457           NaN        NaN     NaN  Right      NaN   NaN    NaN     NaN
#
#     College     Salary    Sport
# 455     NaN  2900000.0  Footbal
# 456  Kansas   947276.0  Footbal
# 457     NaN        NaN  Footbal

# %%
nba.dropna()
# Out:
#               Name            Team  Number   Side Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Right       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Right       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0  Right       SG  22.0    6-5
# 6    Jordan Mickey  Boston Celtics    55.0  Right       PF  21.0    6-8
# 7     Kelly Olynyk  Boston Celtics    41.0  Right        C  25.0    7-0
# ..             ...             ...     ...    ...      ...   ...    ...
# 449    Rodney Hood       Utah Jazz     5.0  Right       SG  23.0    6-8
# 451  Chris Johnson       Utah Jazz    23.0  Right       SF  26.0    6-6
# 452     Trey Lyles       Utah Jazz    41.0  Right       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Right       PG  26.0    6-3
# 456    Jeff Withey       Utah Jazz    24.0  Right        C  26.0    7-0
#
#      Weight        College     Salary    Sport
# 0     180.0          Texas  7730337.0  Footbal
# ...

# %%
nba.dropna(subset=["Salary"])
# Out:
#               Name            Team  Number   Side Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Right       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Right       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0  Right       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Right       PF  29.0   6-10
# 5     Amir Johnson  Boston Celtics    90.0  Right       PF  29.0    6-9
# ..             ...             ...     ...    ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0  Right       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Right       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Right       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Right        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Right        C  26.0    7-0
#
#      Weight        College      Salary    Sport
# 0     180.0          Texas   7730337.0  Footbal
# ...

# %% [markdown]
# # FULLFIL

# %%
nba.fillna(0)
# Out:
#               Name            Team  Number   Side Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Right       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Right       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Right       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Right       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Right       PF  29.0   6-10
# ..             ...             ...     ...    ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Right       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Right       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Right        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Right        C  26.0    7-0
# 457              0               0     0.0  Right        0   0.0      0
#
#      Weight            College     Salary    Sport
# 0     180.0              Texas  7730337.0  Footbal
# ...

# %%
nba["College"].fillna("No College")
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4             No College
#              ...
# 453               Butler
# 454           No College
# 455           No College
# 456               Kansas
# 457           No College
# Name: College, Length: 458, dtype: object

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Side         object
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# Sport        object
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Side      458 non-null    object
#  4   Position  457 non-null    object
#  5   Age       457 non-null    float64
#  6   Height    457 non-null    object
#  7   Weight    457 non-null    float64
#  8   College   373 non-null    object
#  9   Salary    446 non-null    float64
#  10  Sport     458 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 39.5+ KB

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba["Age"]= nba["Age"].astype["int"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d548d5e241be> in <module>
# ----> 1 nba["Age"]= nba["Age"].astype["int"]
#
# TypeError: 'method' object is not subscriptable

# %%
nba["Position"].unique()

# %%
nba["Height"].dtypes

# %%
nba = pd.read_csv("nba.csv")
nba.headad(3)

# %%
nba.sort_values("Age", ascending= False)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# ..              ...                     ...     ...      ...   ...    ...
# 401      Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 60   Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11
# 226   Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122    Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# 304   200.0            Utah   250750.0
# ...

# %%
nba["Salary"].sort_values(ascending = False, na_position= "first")
# Out:
# 2           NaN
# 46          NaN
# 171         NaN
# 264         NaN
# 269         NaN
#          ...
# 175    111196.0
# 135     83397.0
# 291     55722.0
# 130     55722.0
# 32      30888.0
# Name: Salary, Length: 458, dtype: float64

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Name", "Team"]).tail()
# Out:
#                Name                    Team  Number Position   Age Height  \
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# 270   180.0    Rhode Island        NaN
# 402   189.0            UCLA  2148360.0
# 271   260.0  Michigan State  9638555.0
# 237   275.0             NaN  5200000.0
# 457     NaN             NaN        NaN

# %%
nba.sort_values(["Name", "Team"], ascending= False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_index(ascending= False, inplace = True)

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rang"] = nba["Salary"].rank(ascending= False).astype("int")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College   Salary  Salary Rang
# 0                Texas  7730337           97
# ...

# %%
nba.sort_values(by = "Salary", ascending= False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 273   Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
#
#      Weight       College    Salary  Salary Rang
# ...

# %%
nba["College"].dropna()
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 6                    LSU
#              ...
# 449                 Duke
# 451               Dayton
# 452             Kentucky
# 453               Butler
# 456               Kansas
# Name: College, Length: 373, dtype: object

# %%
nba["College"]
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 452             Kentucky
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# Name: College, Length: 457, dtype: object
